# %%
import pandas as pd
import numpy as np
from woe import *
from run_woe import run_WOE
from sklearn.model_selection import train_test_split

# %%
df = pd.read_excel('bank.xlsx')

y  = df['y'].apply(lambda x : 1 if x == 'yes' else 0)  # Convert to numeric
X = df.drop('y',axis=1)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)


X_WOE_tranformed_train, X_WOE_tranformed_test, WOE, WOE_concise, WOE_no_gaps = run_WOE(X_train
, X_test
, y_train
, y_test
, max_cont_bin = 5
)
# Out:
# /Users/michaelcantrell/ds/repos/WOE-and-IV/run_woe.py:112: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   sub_WOE_df.sort_values('MIN_VALUE', inplace = True)
# /Users/michaelcantrell/anaconda/lib/python3.5/site-packages/pandas/core/indexing.py:465: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
WOE
# Out:
#      VAR_NAME      MIN_VALUE      MAX_VALUE  COUNT  EVENT  EVENT_RATE  \
# 0         age             19             33    846    107    0.126478
# 1         age             34             39    672     73    0.108631
# 2         age             40             49    815     83    0.101840
# 3         age             50             87    696    100    0.143678
# 4         job         admin.         admin.    306     42    0.137255
# 5         job    blue-collar    blue-collar    618     47    0.076052
# 6         job   entrepreneur   entrepreneur    103      6    0.058252
# 7         job      housemaid      housemaid     76     11    0.144737
# 8         job     management     management    659     92    0.139605
# 9         job        retired        retired    168     41    0.244048
# 10        job  self-employed  self-employed    131     16    0.122137
# 11        job       services       services    285     26    0.091228
# ...

# %%
X_WOE_tranformed_test.head()
# Out:
#            age       job   marital  education   default   balance   housing  \
# 2398  0.208861 -0.789020 -0.127321  -0.078258  0.276280 -0.408283  0.334369
# 800   0.208861  0.175361 -0.127321   0.244083 -0.004735  0.275834  0.334369
# 2288  0.208861 -0.089886 -0.127321  -0.078258 -0.004735  0.188251  0.334369
# 2344 -0.110870  0.175361 -0.127321   0.244083 -0.004735 -0.408283 -0.342309
# 3615  0.061463  0.155652  0.181734  -0.078258 -0.004735  0.188251  0.334369
#
#           loan   contact       day     month  duration  campaign     pdays  \
# 2398 -0.486335  0.245632  0.005004 -0.266472 -1.158253 -0.346896 -0.269877
# 800   0.071448  0.245632 -0.140773 -0.080288  1.166162  0.109631  0.817683
# 2288  0.071448  0.245632 -0.140773 -0.080288 -1.158253 -0.067048 -0.269877
# 2344  0.071448 -0.950507 -0.140773 -0.016081 -0.033020 -0.346896 -0.269877
# 3615  0.071448  0.245632 -0.140773  0.277396  1.166162  0.109631 -0.269877
#
#       previous  poutcome
# 2398 -0.203709 -0.269877
# ...

# %%
X_test.head()
# Out:
#       age           job  marital  education default  balance housing loan  \
# 2398   51  entrepreneur  married  secondary     yes    -2082      no  yes
# 800    50    management  married   tertiary      no     2881      no   no
# 2288   50    technician  married  secondary      no     1412      no   no
# 2344   37    management  married   tertiary      no        0     yes   no
# 3615   31        admin.   single  secondary      no      757      no   no
#
#        contact  day month  duration  campaign  pdays  previous poutcome
# 2398  cellular   28   jul       123         6     -1         0  unknown
# 800   cellular    5   aug       510         2      2         5    other
# 2288  cellular    6   aug       131         3     -1         0  unknown
# 2344   unknown    3   jun       247        13     -1         0  unknown
# 3615  cellular    3   feb       343         2     -1         0  unknown

# %%
WOE[WOE.VAR_NAME.isin(['age', 'job', 'marital', 'education', 'default', 'balance'])]
# Out:
#      VAR_NAME      MIN_VALUE      MAX_VALUE  COUNT  EVENT  EVENT_RATE  \
# 0         age             19             33    846    107    0.126478
# 1         age             34             39    672     73    0.108631
# 2         age             40             49    815     83    0.101840
# 3         age             50             87    696    100    0.143678
# 4         job         admin.         admin.    306     42    0.137255
# 5         job    blue-collar    blue-collar    618     47    0.076052
# 6         job   entrepreneur   entrepreneur    103      6    0.058252
# 7         job      housemaid      housemaid     76     11    0.144737
# 8         job     management     management    659     92    0.139605
# 9         job        retired        retired    168     41    0.244048
# 10        job  self-employed  self-employed    131     16    0.122137
# 11        job       services       services    285     26    0.091228
# ...
